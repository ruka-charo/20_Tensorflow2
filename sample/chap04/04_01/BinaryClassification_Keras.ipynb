# %%
'''
1.データの準備
'''
import numpy as np
from sklearn.model_selection import train_test_split

# 乱数生成時のシード(種)
np.random.seed(123)

# 入力データの次元
input_dim = 2
# クラスごとのデータ数
n = 500

# 平均(3,2)の正規分布に従うデータを生成
x1 = np.random.randn(n, input_dim) + np.array([3, 2])
# 平均(7,6)の正規分布に従うデータを生成
x2 = np.random.randn(n, input_dim) + np.array([7, 6])
# x1の正解ラベル0を2階テンソルとして生成
t1 = np.array([[0] for i in range(n)])
# x2の正解ラベル1を2階テンソルとして生成
t2 = np.array([[1] for i in range(n)])

# x1、x2を行方向に連結
x = np.concatenate((x1, x2), axis=0)
# t1、t2を行方向に連結
t = np.concatenate((t1, t2), axis=0)

x = x.astype('float32') # 訓練データをfloat64からfloat32に変換
t = t.astype('float32') # 正解ラベルをfloat64からfloat32に変換

# 訓練データと検証データに8：2の割合で分割
x_train, x_validation, t_train, t_validation = \
    train_test_split(x, t, test_size=0.2)

# %%
'''
2. モデルの構築
'''
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers

# モデルオブジェクト(Sequential)を生成
model = Sequential()
# 第1層(隠れ層)を追加
model.add(Dense(2,                     # ユニット数2
                activation='sigmoid')) # シグモイド関数
# 第2層(出力層)を追加
model.add(Dense(1,                     # ユニット数1
                activation='sigmoid')) # シグモイド関数

# オプティマイザーはSGD 学習率はデフォルトの0.1
optimizer = optimizers.SGD(learning_rate=0.1)
# 損失にバイナリー用クロスエントロピーを指定
# 評価関数に精度を求める関数を指定
model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
'''
3. モデルの学習
'''
# エポック数
epoch = 50
# 学習を行う
history = model.fit(x_train,       # 訓練データ
                    t_train,       # 訓練用の正解ラベル
                    epochs=epoch,  # エポック数
                    batch_size=32, # ミニバッチのサイズ
                    verbose=1,     # 進捗状況を出力
                    # 検証データを設定
                    validation_data=(x_validation, t_validation)
                    )

model.summary()
# Out:
# Train on 800 samples, validate on 200 samples
# Epoch 1/50
# 800/800 [==============================] - 1s 689us/sample - loss: 0.6971 - accuracy: 0.4613 - val_loss: 0.6952 - val_accuracy: 0.4850
# Epoch 2/50
# 800/800 [==============================] - 0s 63us/sample - loss: 0.6938 - accuracy: 0.4963 - val_loss: 0.6941 - val_accuracy: 0.4950
# Epoch 3/50
# 800/800 [==============================] - 0s 59us/sample - loss: 0.6914 - accuracy: 0.5250 - val_loss: 0.6927 - val_accuracy: 0.4850
# Epoch 4/50
# 800/800 [==============================] - 0s 59us/sample - loss: 0.6895 - accuracy: 0.5200 - val_loss: 0.6899 - val_accuracy: 0.5400
# Epoch 5/50
# 800/800 [==============================] - 0s 65us/sample - loss: 0.6880 - accuracy: 0.5688 - val_loss: 0.6895 - val_accuracy: 0.5050
# Epoch 6/50
# 800/800 [==============================] - 0s 59us/sample - loss: 0.6867 - accuracy: 0.5462 - val_loss: 0.6878 - val_accuracy: 0.5350
# Epoch 7/50
# 800/800 [==============================] - 0s 60us/sample - loss: 0.6841 - accuracy: 0.5425 - val_loss: 0.6850 - val_accuracy: 0.5750
# Epoch 8/50
# 800/800 [==============================] - 0s 64us/sample - loss: 0.6832 - accuracy: 0.5962 - val_loss: 0.6845 - val_accuracy: 0.5600
# Epoch 9/50
# 800/800 [==============================] - 0s 66us/sample - loss: 0.6810 - accuracy: 0.5763 - val_loss: 0.6819 - val_accuracy: 0.5850
# Epoch 10/50
# 800/800 [==============================] - 0s 54us/sample - loss: 0.6798 - accuracy: 0.5900 - val_loss: 0.6802 - val_accuracy: 0.5850
# Epoch 11/50
# 800/800 [==============================] - 0s 76us/sample - loss: 0.6786 - accuracy: 0.5888 - val_loss: 0.6776 - val_accuracy: 0.6300
# Epoch 12/50
# 800/800 [==============================] - 0s 57us/sample - loss: 0.6757 - accuracy: 0.6187 - val_loss: 0.6760 - val_accuracy: 0.6300
# Epoch 13/50
# 800/800 [==============================] - 0s 56us/sample - loss: 0.6737 - accuracy: 0.6400 - val_loss: 0.6758 - val_accuracy: 0.5850
# Epoch 14/50
# 800/800 [==============================] - 0s 60us/sample - loss: 0.6717 - accuracy: 0.6325 - val_loss: 0.6739 - val_accuracy: 0.5850
# Epoch 15/50
# 800/800 [==============================] - 0s 56us/sample - loss: 0.6692 - accuracy: 0.6438 - val_loss: 0.6728 - val_accuracy: 0.5750
# Epoch 16/50
# 800/800 [==============================] - 0s 54us/sample - loss: 0.6668 - accuracy: 0.6313 - val_loss: 0.6679 - val_accuracy: 0.6300
# Epoch 17/50
# 800/800 [==============================] - 0s 69us/sample - loss: 0.6639 - accuracy: 0.6513 - val_loss: 0.6653 - val_accuracy: 0.6350
# Epoch 18/50
# 800/800 [==============================] - 0s 59us/sample - loss: 0.6613 - accuracy: 0.6600 - val_loss: 0.6620 - val_accuracy: 0.6650
# Epoch 19/50
# 800/800 [==============================] - 0s 57us/sample - loss: 0.6575 - accuracy: 0.7237 - val_loss: 0.6623 - val_accuracy: 0.6050
# Epoch 20/50
# 800/800 [==============================] - 0s 66us/sample - loss: 0.6548 - accuracy: 0.6525 - val_loss: 0.6556 - val_accuracy: 0.6650
# Epoch 21/50
# 800/800 [==============================] - 0s 57us/sample - loss: 0.6496 - accuracy: 0.6700 - val_loss: 0.6503 - val_accuracy: 0.7100
# Epoch 22/50
# 800/800 [==============================] - 0s 59us/sample - loss: 0.6447 - accuracy: 0.7475 - val_loss: 0.6476 - val_accuracy: 0.6600
# Epoch 23/50
# 800/800 [==============================] - 0s 66us/sample - loss: 0.6396 - accuracy: 0.7250 - val_loss: 0.6408 - val_accuracy: 0.7000
# Epoch 24/50
# 800/800 [==============================] - 0s 56us/sample - loss: 0.6331 - accuracy: 0.7575 - val_loss: 0.6356 - val_accuracy: 0.6750
# Epoch 25/50
# 800/800 [==============================] - 0s 55us/sample - loss: 0.6244 - accuracy: 0.7325 - val_loss: 0.6239 - val_accuracy: 0.7550
# Epoch 26/50
# 800/800 [==============================] - 0s 65us/sample - loss: 0.6148 - accuracy: 0.7925 - val_loss: 0.6131 - val_accuracy: 0.7650
# Epoch 27/50
# 800/800 [==============================] - 0s 60us/sample - loss: 0.6008 - accuracy: 0.8213 - val_loss: 0.5992 - val_accuracy: 0.7750
# Epoch 28/50
# 800/800 [==============================] - 0s 56us/sample - loss: 0.5848 - accuracy: 0.8425 - val_loss: 0.5808 - val_accuracy: 0.8400
# Epoch 29/50
# 800/800 [==============================] - 0s 77us/sample - loss: 0.5646 - accuracy: 0.8863 - val_loss: 0.5584 - val_accuracy: 0.8700
# Epoch 30/50
# 800/800 [==============================] - 0s 56us/sample - loss: 0.5414 - accuracy: 0.9175 - val_loss: 0.5296 - val_accuracy: 0.9600
# Epoch 31/50
# 800/800 [==============================] - 0s 64us/sample - loss: 0.5141 - accuracy: 0.9725 - val_loss: 0.5042 - val_accuracy: 0.9350
# Epoch 32/50
# 800/800 [==============================] - 0s 75us/sample - loss: 0.4866 - accuracy: 0.9787 - val_loss: 0.4737 - val_accuracy: 0.9900
# Epoch 33/50
# 800/800 [==============================] - 0s 71us/sample - loss: 0.4596 - accuracy: 0.9912 - val_loss: 0.4470 - val_accuracy: 0.9850
# Epoch 34/50
# 800/800 [==============================] - 0s 68us/sample - loss: 0.4352 - accuracy: 0.9850 - val_loss: 0.4218 - val_accuracy: 0.9900
# Epoch 35/50
# 800/800 [==============================] - 0s 59us/sample - loss: 0.4091 - accuracy: 0.9875 - val_loss: 0.3979 - val_accuracy: 0.9850
# Epoch 36/50
# 800/800 [==============================] - 0s 54us/sample - loss: 0.3863 - accuracy: 0.9887 - val_loss: 0.3759 - val_accuracy: 0.9750
# Epoch 37/50
# 800/800 [==============================] - 0s 61us/sample - loss: 0.3643 - accuracy: 0.9875 - val_loss: 0.3575 - val_accuracy: 0.9700
# Epoch 38/50
# 800/800 [==============================] - 0s 62us/sample - loss: 0.3441 - accuracy: 0.9887 - val_loss: 0.3350 - val_accuracy: 0.9750
# Epoch 39/50
# 800/800 [==============================] - 0s 58us/sample - loss: 0.3236 - accuracy: 0.9912 - val_loss: 0.3202 - val_accuracy: 0.9700
# Epoch 40/50
# 800/800 [==============================] - 0s 61us/sample - loss: 0.3052 - accuracy: 0.9925 - val_loss: 0.2977 - val_accuracy: 0.9850
# Epoch 41/50
# 800/800 [==============================] - 0s 61us/sample - loss: 0.2875 - accuracy: 0.9950 - val_loss: 0.2848 - val_accuracy: 0.9750
# Epoch 42/50
# 800/800 [==============================] - 0s 59us/sample - loss: 0.2717 - accuracy: 0.9925 - val_loss: 0.2653 - val_accuracy: 0.9900
# Epoch 43/50
# 800/800 [==============================] - 0s 60us/sample - loss: 0.2572 - accuracy: 0.9937 - val_loss: 0.2514 - val_accuracy: 0.9850
# Epoch 44/50
# 800/800 [==============================] - 0s 66us/sample - loss: 0.2419 - accuracy: 0.9937 - val_loss: 0.2375 - val_accuracy: 0.9900
# Epoch 45/50
# 800/800 [==============================] - 0s 58us/sample - loss: 0.2293 - accuracy: 0.9950 - val_loss: 0.2265 - val_accuracy: 0.9850
# Epoch 46/50
# 800/800 [==============================] - 0s 64us/sample - loss: 0.2178 - accuracy: 0.9937 - val_loss: 0.2133 - val_accuracy: 0.9900
# Epoch 47/50
# 800/800 [==============================] - 0s 68us/sample - loss: 0.2062 - accuracy: 0.9950 - val_loss: 0.2027 - val_accuracy: 0.9950
# Epoch 48/50
# 800/800 [==============================] - 0s 61us/sample - loss: 0.1971 - accuracy: 0.9937 - val_loss: 0.1923 - val_accuracy: 0.9950
# Epoch 49/50
# 800/800 [==============================] - 0s 64us/sample - loss: 0.1862 - accuracy: 0.9950 - val_loss: 0.1838 - val_accuracy: 0.9900
# Epoch 50/50
# 800/800 [==============================] - 0s 61us/sample - loss: 0.1776 - accuracy: 0.9950 - val_loss: 0.1757 - val_accuracy: 0.9900
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  6
# _________________________________________________________________
# dense_1 (Dense)              multiple                  3
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
