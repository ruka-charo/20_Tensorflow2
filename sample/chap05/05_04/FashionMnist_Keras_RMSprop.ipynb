# %%
'''
1. データセットの読み込みと正規化
'''
# tensorflow.keras のインポート
from tensorflow import keras

# Fashion-MNISTデータセットの読み込み
(x_train, t_train), (x_test, t_test) = keras.datasets.fashion_mnist.load_data()

# 訓練データを正規化
x_train = x_train / 255
# テストデータを正規化
x_test = x_test / 255

# %%
'''
2.モデルの生成
'''
# モデルオブジェクトを生成
model = keras.Sequential([
    # 入力するテンソルの形状を(28, 28)から(784)にフラット化する
    keras.layers.Flatten(input_shape=(28, 28)),
    # 隠れ層のユニット数:256
    # 活性化関数:ReLU
    keras.layers.Dense(256, activation='relu'),
    # 出力層のニューロン数:10
    # 活性化関数:ソフトマックス 
    keras.layers.Dense(10, activation='softmax')
])

# 学習率
learning_rate = 0.1                  
# モデルのコンパイル
model.compile(
    # 損失関数はスパースラベル対応クロスエントロピー誤差
    loss='sparse_categorical_crossentropy',
    # オプティマイザーはRMSprop
    optimizer=keras.optimizers.RMSprop(learning_rate=0.001),
    # 学習評価として正解率を指定
    metrics=['accuracy']
    )

model.summary() # モデルのサマリー(概要)を出力
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
'''
3. モデルの学習
'''
epoch = 100
# ミニバッチのサイズ
batch_size = 64

history = model.fit(
    x_train,               # 訓練データ
    t_train,               # 正解ラベル
    epochs=epoch,          # エポック数を設定
    batch_size=batch_size, # ミニバッチのサイズを設定
    verbose=1,             # 進捗状況を出力
    validation_split=0.2   # 20パーセントのデータを検証に使用
    )
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/100
# 48000/48000 [==============================] - 4s 79us/sample - loss: 0.5505 - accuracy: 0.8045 - val_loss: 0.3983 - val_accuracy: 0.8584
# Epoch 2/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.3894 - accuracy: 0.8585 - val_loss: 0.3940 - val_accuracy: 0.8512
# Epoch 3/100
# 48000/48000 [==============================] - 3s 71us/sample - loss: 0.3436 - accuracy: 0.8750 - val_loss: 0.3601 - val_accuracy: 0.8701
# Epoch 4/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.3187 - accuracy: 0.8835 - val_loss: 0.3342 - val_accuracy: 0.8808
# Epoch 5/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.3014 - accuracy: 0.8906 - val_loss: 0.3424 - val_accuracy: 0.8792
# Epoch 6/100
# 48000/48000 [==============================] - 3s 71us/sample - loss: 0.2869 - accuracy: 0.8945 - val_loss: 0.3856 - val_accuracy: 0.8663
# Epoch 7/100
# 48000/48000 [==============================] - 3s 71us/sample - loss: 0.2745 - accuracy: 0.9006 - val_loss: 0.3399 - val_accuracy: 0.8872
# Epoch 8/100
# 48000/48000 [==============================] - 3s 71us/sample - loss: 0.2639 - accuracy: 0.9034 - val_loss: 0.3317 - val_accuracy: 0.8876
# Epoch 9/100
# 48000/48000 [==============================] - 3s 71us/sample - loss: 0.2552 - accuracy: 0.9078 - val_loss: 0.3584 - val_accuracy: 0.8806
# Epoch 10/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.2483 - accuracy: 0.9101 - val_loss: 0.3467 - val_accuracy: 0.8917
# Epoch 11/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.2405 - accuracy: 0.9127 - val_loss: 0.3511 - val_accuracy: 0.8916
# Epoch 12/100
# 48000/48000 [==============================] - 3s 72us/sample - loss: 0.2343 - accuracy: 0.9151 - val_loss: 0.3434 - val_accuracy: 0.8900
# Epoch 13/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.2267 - accuracy: 0.9181 - val_loss: 0.3536 - val_accuracy: 0.8915
# Epoch 14/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.2192 - accuracy: 0.9198 - val_loss: 0.3613 - val_accuracy: 0.8906
# Epoch 15/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.2149 - accuracy: 0.9219 - val_loss: 0.3557 - val_accuracy: 0.8928
# Epoch 16/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.2072 - accuracy: 0.9251 - val_loss: 0.3525 - val_accuracy: 0.8960
# Epoch 17/100
# 48000/48000 [==============================] - 3s 70us/sample - loss: 0.2036 - accuracy: 0.9259 - val_loss: 0.3821 - val_accuracy: 0.8880
# Epoch 18/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.1953 - accuracy: 0.9307 - val_loss: 0.4015 - val_accuracy: 0.8832
# Epoch 19/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.1921 - accuracy: 0.9315 - val_loss: 0.4082 - val_accuracy: 0.8870
# Epoch 20/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.1869 - accuracy: 0.9326 - val_loss: 0.4054 - val_accuracy: 0.8838
# Epoch 21/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.1833 - accuracy: 0.9342 - val_loss: 0.4238 - val_accuracy: 0.8898
# Epoch 22/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.1775 - accuracy: 0.9356 - val_loss: 0.4316 - val_accuracy: 0.8863
# Epoch 23/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.1739 - accuracy: 0.9374 - val_loss: 0.4217 - val_accuracy: 0.8923
# Epoch 24/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.1702 - accuracy: 0.9394 - val_loss: 0.4404 - val_accuracy: 0.8900
# Epoch 25/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.1686 - accuracy: 0.9410 - val_loss: 0.4619 - val_accuracy: 0.8917
# Epoch 26/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.1636 - accuracy: 0.9420 - val_loss: 0.4470 - val_accuracy: 0.8882
# Epoch 27/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.1619 - accuracy: 0.9427 - val_loss: 0.4926 - val_accuracy: 0.8876
# Epoch 28/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.1567 - accuracy: 0.9443 - val_loss: 0.4545 - val_accuracy: 0.8953
# Epoch 29/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.1511 - accuracy: 0.9455 - val_loss: 0.4874 - val_accuracy: 0.8923
# Epoch 30/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.1519 - accuracy: 0.9457 - val_loss: 0.4607 - val_accuracy: 0.8912
# Epoch 31/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.1502 - accuracy: 0.9483 - val_loss: 0.4768 - val_accuracy: 0.8936
# Epoch 32/100
# 48000/48000 [==============================] - 3s 72us/sample - loss: 0.1441 - accuracy: 0.9491 - val_loss: 0.5134 - val_accuracy: 0.8892
# Epoch 33/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.1459 - accuracy: 0.9493 - val_loss: 0.5180 - val_accuracy: 0.8871
# Epoch 34/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.1398 - accuracy: 0.9510 - val_loss: 0.4824 - val_accuracy: 0.8925
# Epoch 35/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.1364 - accuracy: 0.9522 - val_loss: 0.5219 - val_accuracy: 0.8920
# Epoch 36/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.1350 - accuracy: 0.9527 - val_loss: 0.5364 - val_accuracy: 0.8852
# Epoch 37/100
# 48000/48000 [==============================] - 3s 71us/sample - loss: 0.1330 - accuracy: 0.9533 - val_loss: 0.5315 - val_accuracy: 0.8909
# Epoch 38/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.1286 - accuracy: 0.9541 - val_loss: 0.5703 - val_accuracy: 0.8851
# Epoch 39/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.1295 - accuracy: 0.9556 - val_loss: 0.5666 - val_accuracy: 0.8914
# Epoch 40/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.1238 - accuracy: 0.9572 - val_loss: 0.5799 - val_accuracy: 0.8883
# Epoch 41/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.1230 - accuracy: 0.9573 - val_loss: 0.5532 - val_accuracy: 0.8900
# Epoch 42/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.1189 - accuracy: 0.9586 - val_loss: 0.6189 - val_accuracy: 0.8868
# Epoch 43/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.1232 - accuracy: 0.9586 - val_loss: 0.6509 - val_accuracy: 0.8854
# Epoch 44/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.1189 - accuracy: 0.9591 - val_loss: 0.6306 - val_accuracy: 0.8865
# Epoch 45/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.1151 - accuracy: 0.9606 - val_loss: 0.6354 - val_accuracy: 0.8913
# Epoch 46/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.1138 - accuracy: 0.9610 - val_loss: 0.5992 - val_accuracy: 0.8937
# Epoch 47/100
# 48000/48000 [==============================] - 3s 71us/sample - loss: 0.1147 - accuracy: 0.9611 - val_loss: 0.6282 - val_accuracy: 0.8912
# Epoch 48/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.1122 - accuracy: 0.9610 - val_loss: 0.6464 - val_accuracy: 0.8902
# Epoch 49/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.1058 - accuracy: 0.9635 - val_loss: 0.6388 - val_accuracy: 0.8882
# Epoch 50/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.1076 - accuracy: 0.9629 - val_loss: 0.6573 - val_accuracy: 0.8843
# Epoch 51/100
# 48000/48000 [==============================] - 3s 70us/sample - loss: 0.1070 - accuracy: 0.9644 - val_loss: 0.6715 - val_accuracy: 0.8879
# Epoch 52/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.1062 - accuracy: 0.9638 - val_loss: 0.6597 - val_accuracy: 0.8935
# Epoch 53/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.1041 - accuracy: 0.9661 - val_loss: 0.6671 - val_accuracy: 0.8903
# Epoch 54/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.0987 - accuracy: 0.9668 - val_loss: 0.7418 - val_accuracy: 0.8842
# Epoch 55/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.1004 - accuracy: 0.9660 - val_loss: 0.7388 - val_accuracy: 0.8880
# Epoch 56/100
# 48000/48000 [==============================] - 4s 73us/sample - loss: 0.0980 - accuracy: 0.9673 - val_loss: 0.6854 - val_accuracy: 0.8938
# Epoch 57/100
# 48000/48000 [==============================] - 3s 70us/sample - loss: 0.0945 - accuracy: 0.9683 - val_loss: 0.7145 - val_accuracy: 0.8899
# Epoch 58/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.0961 - accuracy: 0.9687 - val_loss: 0.7644 - val_accuracy: 0.8838
# Epoch 59/100
# 48000/48000 [==============================] - 3s 71us/sample - loss: 0.0930 - accuracy: 0.9693 - val_loss: 0.7212 - val_accuracy: 0.8929
# Epoch 60/100
# 48000/48000 [==============================] - 4s 73us/sample - loss: 0.0946 - accuracy: 0.9690 - val_loss: 0.7821 - val_accuracy: 0.8908
# Epoch 61/100
# 48000/48000 [==============================] - 3s 72us/sample - loss: 0.0924 - accuracy: 0.9697 - val_loss: 0.7340 - val_accuracy: 0.8895
# Epoch 62/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.0910 - accuracy: 0.9711 - val_loss: 0.7600 - val_accuracy: 0.8927
# Epoch 63/100
# 48000/48000 [==============================] - 3s 65us/sample - loss: 0.0928 - accuracy: 0.9702 - val_loss: 0.8531 - val_accuracy: 0.8904
# Epoch 64/100
# 48000/48000 [==============================] - 3s 65us/sample - loss: 0.0894 - accuracy: 0.9708 - val_loss: 0.8234 - val_accuracy: 0.8845
# Epoch 65/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.0874 - accuracy: 0.9714 - val_loss: 0.8068 - val_accuracy: 0.8902
# Epoch 66/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.0863 - accuracy: 0.9716 - val_loss: 0.7929 - val_accuracy: 0.8896
# Epoch 67/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.0870 - accuracy: 0.9713 - val_loss: 0.8794 - val_accuracy: 0.8841
# Epoch 68/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.0880 - accuracy: 0.9726 - val_loss: 0.8960 - val_accuracy: 0.8902
# Epoch 69/100
# 48000/48000 [==============================] - 3s 65us/sample - loss: 0.0889 - accuracy: 0.9724 - val_loss: 0.8659 - val_accuracy: 0.8918
# Epoch 70/100
# 48000/48000 [==============================] - 3s 65us/sample - loss: 0.0824 - accuracy: 0.9729 - val_loss: 0.8822 - val_accuracy: 0.8892
# Epoch 71/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.0797 - accuracy: 0.9741 - val_loss: 0.9094 - val_accuracy: 0.8849
# Epoch 72/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.0836 - accuracy: 0.9741 - val_loss: 0.9107 - val_accuracy: 0.8840
# Epoch 73/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.0822 - accuracy: 0.9743 - val_loss: 0.8478 - val_accuracy: 0.8922
# Epoch 74/100
# 48000/48000 [==============================] - 3s 65us/sample - loss: 0.0809 - accuracy: 0.9743 - val_loss: 0.9029 - val_accuracy: 0.8865
# Epoch 75/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.0808 - accuracy: 0.9744 - val_loss: 0.8968 - val_accuracy: 0.8859
# Epoch 76/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.0773 - accuracy: 0.9757 - val_loss: 0.9414 - val_accuracy: 0.8857
# Epoch 77/100
# 48000/48000 [==============================] - 3s 65us/sample - loss: 0.0755 - accuracy: 0.9755 - val_loss: 0.9053 - val_accuracy: 0.8876
# Epoch 78/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.0768 - accuracy: 0.9761 - val_loss: 0.8950 - val_accuracy: 0.8891
# Epoch 79/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.0760 - accuracy: 0.9761 - val_loss: 1.0174 - val_accuracy: 0.8875
# Epoch 80/100
# 48000/48000 [==============================] - 3s 71us/sample - loss: 0.0753 - accuracy: 0.9769 - val_loss: 1.0561 - val_accuracy: 0.8897
# Epoch 81/100
# 48000/48000 [==============================] - 3s 73us/sample - loss: 0.0738 - accuracy: 0.9774 - val_loss: 0.9464 - val_accuracy: 0.8894
# Epoch 82/100
# 48000/48000 [==============================] - 3s 72us/sample - loss: 0.0742 - accuracy: 0.9761 - val_loss: 1.0250 - val_accuracy: 0.8844
# Epoch 83/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.0767 - accuracy: 0.9769 - val_loss: 0.9880 - val_accuracy: 0.8874
# Epoch 84/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.0708 - accuracy: 0.9779 - val_loss: 0.9995 - val_accuracy: 0.8876
# Epoch 85/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.0718 - accuracy: 0.9771 - val_loss: 1.0086 - val_accuracy: 0.8886
# Epoch 86/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.0685 - accuracy: 0.9790 - val_loss: 0.9852 - val_accuracy: 0.8873
# Epoch 87/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.0701 - accuracy: 0.9784 - val_loss: 1.0057 - val_accuracy: 0.8892
# Epoch 88/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.0675 - accuracy: 0.9785 - val_loss: 1.0274 - val_accuracy: 0.8868
# Epoch 89/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.0680 - accuracy: 0.9796 - val_loss: 1.0281 - val_accuracy: 0.8861
# Epoch 90/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.0672 - accuracy: 0.9795 - val_loss: 1.0799 - val_accuracy: 0.8852
# Epoch 91/100
# 48000/48000 [==============================] - 4s 73us/sample - loss: 0.0680 - accuracy: 0.9793 - val_loss: 1.0593 - val_accuracy: 0.8872
# Epoch 92/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.0649 - accuracy: 0.9797 - val_loss: 1.0836 - val_accuracy: 0.8842
# Epoch 93/100
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.0682 - accuracy: 0.9797 - val_loss: 1.1541 - val_accuracy: 0.8843
# Epoch 94/100
# 48000/48000 [==============================] - 4s 74us/sample - loss: 0.0628 - accuracy: 0.9798 - val_loss: 1.0941 - val_accuracy: 0.8907
# Epoch 95/100
# 48000/48000 [==============================] - 4s 73us/sample - loss: 0.0659 - accuracy: 0.9797 - val_loss: 1.0649 - val_accuracy: 0.8903
# Epoch 96/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.0680 - accuracy: 0.9801 - val_loss: 1.0595 - val_accuracy: 0.8917
# Epoch 97/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.0644 - accuracy: 0.9808 - val_loss: 1.0772 - val_accuracy: 0.8877
# Epoch 98/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.0585 - accuracy: 0.9820 - val_loss: 1.1470 - val_accuracy: 0.8873
# Epoch 99/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.0595 - accuracy: 0.9819 - val_loss: 1.1478 - val_accuracy: 0.8838
# Epoch 100/100
# 48000/48000 [==============================] - 3s 72us/sample - loss: 0.0651 - accuracy: 0.9808 - val_loss: 1.1658 - val_accuracy: 0.8785
# Wall time: 5min 28s

# %%
'''
4. テストデータによるモデルの評価
'''
# 学習済みのモデルにテストデータを入力して損失と精度を取得
test_loss, test_acc = model.evaluate(x_test, t_test, verbose=0)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
# Out:
# test_loss: 1.232753902770113
# test_acc: 0.876
