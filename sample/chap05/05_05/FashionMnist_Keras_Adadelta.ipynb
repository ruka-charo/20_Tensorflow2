# %%
'''
1. データセットの読み込みと正規化
'''
# tensorflow.keras のインポート
from tensorflow import keras

# Fashion-MNISTデータセットの読み込み
(x_train, t_train), (x_test, t_test) = keras.datasets.fashion_mnist.load_data()

# 訓練データを正規化
x_train = x_train / 255
# テストデータを正規化
x_test = x_test / 255

# %%
'''
2.モデルの生成
'''
# モデルオブジェクトを生成
model = keras.Sequential([
    # 入力するテンソルの形状を(28, 28)から(784)にフラット化する
    keras.layers.Flatten(input_shape=(28, 28)),
    # 隠れ層のユニット数:256
    # 活性化関数:ReLU
    keras.layers.Dense(256, activation='relu'),
    # 出力層のニューロン数:10
    # 活性化関数:ソフトマックス 
    keras.layers.Dense(10, activation='softmax')
])

# モデルのコンパイル
model.compile(
    # 損失関数はスパースラベル対応クロスエントロピー誤差
    loss='sparse_categorical_crossentropy',
    # オプティマイザーはAdadelta
    optimizer=keras.optimizers.Adadelta(learning_rate=1.0),
    # 学習評価として正解率を指定
    metrics=['accuracy']
    )

model.summary() # モデルのサマリー(概要)を出力
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
'''
3. モデルの学習
'''
epoch = 100
# ミニバッチのサイズ
batch_size = 64

history = model.fit(
    x_train,               # 訓練データ
    t_train,               # 正解ラベル
    epochs=epoch,          # エポック数を設定
    batch_size=batch_size, # ミニバッチのサイズを設定
    verbose=1,             # 進捗状況を出力
    validation_split=0.2   # 20パーセントのデータを検証に使用
    )
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/100
# 48000/48000 [==============================] - 4s 74us/sample - loss: 0.5588 - accuracy: 0.8014 - val_loss: 0.4714 - val_accuracy: 0.8332
# Epoch 2/100
# 48000/48000 [==============================] - 3s 65us/sample - loss: 0.3968 - accuracy: 0.8567 - val_loss: 0.3626 - val_accuracy: 0.8681
# Epoch 3/100
# 48000/48000 [==============================] - 3s 65us/sample - loss: 0.3533 - accuracy: 0.8713 - val_loss: 0.3789 - val_accuracy: 0.8607
# Epoch 4/100
# 48000/48000 [==============================] - 3s 64us/sample - loss: 0.3251 - accuracy: 0.8809 - val_loss: 0.3439 - val_accuracy: 0.8735
# Epoch 5/100
# 48000/48000 [==============================] - 3s 64us/sample - loss: 0.3048 - accuracy: 0.8869 - val_loss: 0.3404 - val_accuracy: 0.8793
# Epoch 6/100
# 48000/48000 [==============================] - 3s 64us/sample - loss: 0.2897 - accuracy: 0.8947 - val_loss: 0.3338 - val_accuracy: 0.8794
# Epoch 7/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.2760 - accuracy: 0.8982 - val_loss: 0.3218 - val_accuracy: 0.8848
# Epoch 8/100
# 48000/48000 [==============================] - 3s 64us/sample - loss: 0.2634 - accuracy: 0.9036 - val_loss: 0.3106 - val_accuracy: 0.8888
# Epoch 9/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.2533 - accuracy: 0.9071 - val_loss: 0.3176 - val_accuracy: 0.8892
# Epoch 10/100
# 48000/48000 [==============================] - 3s 65us/sample - loss: 0.2445 - accuracy: 0.9109 - val_loss: 0.3052 - val_accuracy: 0.8895
# Epoch 11/100
# 48000/48000 [==============================] - 3s 63us/sample - loss: 0.2346 - accuracy: 0.9128 - val_loss: 0.2996 - val_accuracy: 0.8957
# Epoch 12/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.2273 - accuracy: 0.9164 - val_loss: 0.3181 - val_accuracy: 0.8881
# Epoch 13/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.2190 - accuracy: 0.9195 - val_loss: 0.3074 - val_accuracy: 0.8938
# Epoch 14/100
# 48000/48000 [==============================] - 3s 63us/sample - loss: 0.2115 - accuracy: 0.9231 - val_loss: 0.3146 - val_accuracy: 0.8912
# Epoch 15/100
# 48000/48000 [==============================] - 3s 64us/sample - loss: 0.2063 - accuracy: 0.9230 - val_loss: 0.3026 - val_accuracy: 0.8958
# Epoch 16/100
# 48000/48000 [==============================] - 3s 64us/sample - loss: 0.1994 - accuracy: 0.9272 - val_loss: 0.3136 - val_accuracy: 0.8963
# Epoch 17/100
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.1927 - accuracy: 0.9300 - val_loss: 0.3016 - val_accuracy: 0.8963
# Epoch 18/100
# 48000/48000 [==============================] - 3s 63us/sample - loss: 0.1869 - accuracy: 0.9312 - val_loss: 0.3344 - val_accuracy: 0.8907
# Epoch 19/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.1824 - accuracy: 0.9323 - val_loss: 0.3255 - val_accuracy: 0.8914
# Epoch 20/100
# 48000/48000 [==============================] - 3s 65us/sample - loss: 0.1770 - accuracy: 0.9338 - val_loss: 0.3046 - val_accuracy: 0.8975
# Epoch 21/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1719 - accuracy: 0.9368 - val_loss: 0.3392 - val_accuracy: 0.8864
# Epoch 22/100
# 48000/48000 [==============================] - 3s 64us/sample - loss: 0.1674 - accuracy: 0.9384 - val_loss: 0.3230 - val_accuracy: 0.8939
# Epoch 23/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.1622 - accuracy: 0.9409 - val_loss: 0.3173 - val_accuracy: 0.8945
# Epoch 24/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1583 - accuracy: 0.9417 - val_loss: 0.3336 - val_accuracy: 0.8902
# Epoch 25/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1526 - accuracy: 0.9437 - val_loss: 0.3367 - val_accuracy: 0.8948
# Epoch 26/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1490 - accuracy: 0.9452 - val_loss: 0.3637 - val_accuracy: 0.8870
# Epoch 27/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1455 - accuracy: 0.9473 - val_loss: 0.3479 - val_accuracy: 0.8901
# Epoch 28/100
# 48000/48000 [==============================] - 3s 65us/sample - loss: 0.1426 - accuracy: 0.9480 - val_loss: 0.3565 - val_accuracy: 0.8907
# Epoch 29/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1376 - accuracy: 0.9510 - val_loss: 0.3634 - val_accuracy: 0.8910
# Epoch 30/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1340 - accuracy: 0.9508 - val_loss: 0.3748 - val_accuracy: 0.8878
# Epoch 31/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.1308 - accuracy: 0.9514 - val_loss: 0.3439 - val_accuracy: 0.8961
# Epoch 32/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1260 - accuracy: 0.9540 - val_loss: 0.3403 - val_accuracy: 0.8970
# Epoch 33/100
# 48000/48000 [==============================] - 3s 64us/sample - loss: 0.1246 - accuracy: 0.9539 - val_loss: 0.3432 - val_accuracy: 0.8981
# Epoch 34/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1201 - accuracy: 0.9570 - val_loss: 0.3508 - val_accuracy: 0.8963
# Epoch 35/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1164 - accuracy: 0.9574 - val_loss: 0.3690 - val_accuracy: 0.8933
# Epoch 36/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1148 - accuracy: 0.9584 - val_loss: 0.3655 - val_accuracy: 0.8978
# Epoch 37/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1111 - accuracy: 0.9594 - val_loss: 0.3843 - val_accuracy: 0.8913
# Epoch 38/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.1094 - accuracy: 0.9604 - val_loss: 0.3669 - val_accuracy: 0.8942
# Epoch 39/100
# 48000/48000 [==============================] - 3s 63us/sample - loss: 0.1073 - accuracy: 0.9617 - val_loss: 0.3746 - val_accuracy: 0.8909
# Epoch 40/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1041 - accuracy: 0.9627 - val_loss: 0.3905 - val_accuracy: 0.8864
# Epoch 41/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.1004 - accuracy: 0.9643 - val_loss: 0.3855 - val_accuracy: 0.8963
# Epoch 42/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.0980 - accuracy: 0.9643 - val_loss: 0.3855 - val_accuracy: 0.8955
# Epoch 43/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0959 - accuracy: 0.9661 - val_loss: 0.3945 - val_accuracy: 0.8937
# Epoch 44/100
# 48000/48000 [==============================] - 3s 64us/sample - loss: 0.0942 - accuracy: 0.9660 - val_loss: 0.3955 - val_accuracy: 0.8924
# Epoch 45/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0912 - accuracy: 0.9668 - val_loss: 0.3949 - val_accuracy: 0.8962
# Epoch 46/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0891 - accuracy: 0.9678 - val_loss: 0.3957 - val_accuracy: 0.8960
# Epoch 47/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.0885 - accuracy: 0.9684 - val_loss: 0.3958 - val_accuracy: 0.8993
# Epoch 48/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.0856 - accuracy: 0.9685 - val_loss: 0.4210 - val_accuracy: 0.8910
# Epoch 49/100
# 48000/48000 [==============================] - 3s 65us/sample - loss: 0.0833 - accuracy: 0.9697 - val_loss: 0.4068 - val_accuracy: 0.8937
# Epoch 50/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.0818 - accuracy: 0.9700 - val_loss: 0.4116 - val_accuracy: 0.8947
# Epoch 51/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0784 - accuracy: 0.9710 - val_loss: 0.4322 - val_accuracy: 0.8959
# Epoch 52/100
# 48000/48000 [==============================] - 3s 64us/sample - loss: 0.0774 - accuracy: 0.9719 - val_loss: 0.4317 - val_accuracy: 0.8912
# Epoch 53/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.0763 - accuracy: 0.9724 - val_loss: 0.4093 - val_accuracy: 0.8949
# Epoch 54/100
# 48000/48000 [==============================] - 3s 64us/sample - loss: 0.0739 - accuracy: 0.9733 - val_loss: 0.4282 - val_accuracy: 0.8947
# Epoch 55/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0709 - accuracy: 0.9753 - val_loss: 0.4358 - val_accuracy: 0.8934
# Epoch 56/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0698 - accuracy: 0.9751 - val_loss: 0.4288 - val_accuracy: 0.8975
# Epoch 57/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0682 - accuracy: 0.9750 - val_loss: 0.4650 - val_accuracy: 0.8917
# Epoch 58/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0665 - accuracy: 0.9758 - val_loss: 0.4479 - val_accuracy: 0.8977
# Epoch 59/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0644 - accuracy: 0.9764 - val_loss: 0.4470 - val_accuracy: 0.8931
# Epoch 60/100
# 48000/48000 [==============================] - 3s 64us/sample - loss: 0.0638 - accuracy: 0.9770 - val_loss: 0.4447 - val_accuracy: 0.8939
# Epoch 61/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0629 - accuracy: 0.9781 - val_loss: 0.4552 - val_accuracy: 0.8975
# Epoch 62/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0617 - accuracy: 0.9776 - val_loss: 0.4633 - val_accuracy: 0.8932
# Epoch 63/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0589 - accuracy: 0.9793 - val_loss: 0.4658 - val_accuracy: 0.8921
# Epoch 64/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0588 - accuracy: 0.9790 - val_loss: 0.4731 - val_accuracy: 0.8942
# Epoch 65/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0556 - accuracy: 0.9798 - val_loss: 0.4879 - val_accuracy: 0.8948
# Epoch 66/100
# 48000/48000 [==============================] - 3s 65us/sample - loss: 0.0545 - accuracy: 0.9803 - val_loss: 0.4905 - val_accuracy: 0.8937
# Epoch 67/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0542 - accuracy: 0.9805 - val_loss: 0.4818 - val_accuracy: 0.8917
# Epoch 68/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0527 - accuracy: 0.9815 - val_loss: 0.4718 - val_accuracy: 0.8957
# Epoch 69/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0519 - accuracy: 0.9811 - val_loss: 0.4742 - val_accuracy: 0.8943
# Epoch 70/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0501 - accuracy: 0.9830 - val_loss: 0.4766 - val_accuracy: 0.8962
# Epoch 71/100
# 48000/48000 [==============================] - 3s 63us/sample - loss: 0.0506 - accuracy: 0.9821 - val_loss: 0.5295 - val_accuracy: 0.8895
# Epoch 72/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0484 - accuracy: 0.9830 - val_loss: 0.4951 - val_accuracy: 0.8898
# Epoch 73/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0481 - accuracy: 0.9827 - val_loss: 0.5034 - val_accuracy: 0.8928
# Epoch 74/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0460 - accuracy: 0.9841 - val_loss: 0.5338 - val_accuracy: 0.8916
# Epoch 75/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0457 - accuracy: 0.9842 - val_loss: 0.5138 - val_accuracy: 0.8979
# Epoch 76/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0446 - accuracy: 0.9849 - val_loss: 0.5205 - val_accuracy: 0.8954
# Epoch 77/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0446 - accuracy: 0.9844 - val_loss: 0.5320 - val_accuracy: 0.8914
# Epoch 78/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0425 - accuracy: 0.9851 - val_loss: 0.5189 - val_accuracy: 0.8940
# Epoch 79/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0397 - accuracy: 0.9863 - val_loss: 0.5358 - val_accuracy: 0.8958
# Epoch 80/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0408 - accuracy: 0.9850 - val_loss: 0.5620 - val_accuracy: 0.8890
# Epoch 81/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0382 - accuracy: 0.9866 - val_loss: 0.5508 - val_accuracy: 0.8905
# Epoch 82/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.0392 - accuracy: 0.9862 - val_loss: 0.5521 - val_accuracy: 0.8935
# Epoch 83/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0376 - accuracy: 0.9868 - val_loss: 0.5478 - val_accuracy: 0.8942
# Epoch 84/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.0373 - accuracy: 0.9870 - val_loss: 0.5602 - val_accuracy: 0.8957
# Epoch 85/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0361 - accuracy: 0.9872 - val_loss: 0.5810 - val_accuracy: 0.8873
# Epoch 86/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0359 - accuracy: 0.9870 - val_loss: 0.6093 - val_accuracy: 0.8923
# Epoch 87/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0354 - accuracy: 0.9877 - val_loss: 0.5636 - val_accuracy: 0.8936
# Epoch 88/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0335 - accuracy: 0.9885 - val_loss: 0.5508 - val_accuracy: 0.8942
# Epoch 89/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0333 - accuracy: 0.9890 - val_loss: 0.5823 - val_accuracy: 0.8935
# Epoch 90/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0317 - accuracy: 0.9887 - val_loss: 0.5772 - val_accuracy: 0.8928
# Epoch 91/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0316 - accuracy: 0.9891 - val_loss: 0.6216 - val_accuracy: 0.8907
# Epoch 92/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0309 - accuracy: 0.9896 - val_loss: 0.5922 - val_accuracy: 0.8941
# Epoch 93/100
# 48000/48000 [==============================] - 3s 63us/sample - loss: 0.0309 - accuracy: 0.9891 - val_loss: 0.5948 - val_accuracy: 0.8909
# Epoch 94/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0297 - accuracy: 0.9898 - val_loss: 0.5742 - val_accuracy: 0.8958
# Epoch 95/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0287 - accuracy: 0.9901 - val_loss: 0.5970 - val_accuracy: 0.8917
# Epoch 96/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0278 - accuracy: 0.9904 - val_loss: 0.5967 - val_accuracy: 0.8903
# Epoch 97/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0289 - accuracy: 0.9897 - val_loss: 0.6036 - val_accuracy: 0.8933
# Epoch 98/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0278 - accuracy: 0.9905 - val_loss: 0.6040 - val_accuracy: 0.8941
# Epoch 99/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.0265 - accuracy: 0.9907 - val_loss: 0.6050 - val_accuracy: 0.8947
# Epoch 100/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0265 - accuracy: 0.9906 - val_loss: 0.6096 - val_accuracy: 0.8907
# Wall time: 4min 57s

# %%
'''
4. テストデータによるモデルの評価
'''
# 学習済みのモデルにテストデータを入力して損失と精度を取得
test_loss, test_acc = model.evaluate(x_test, t_test, verbose=0)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
# Out:
# test_loss: 0.6583577468153089
# test_acc: 0.8906
