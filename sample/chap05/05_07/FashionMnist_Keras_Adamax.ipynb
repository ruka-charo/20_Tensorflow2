# %%
'''
1. データセットの読み込みと正規化
'''
# tensorflow.keras のインポート
from tensorflow import keras

# Fashion-MNISTデータセットの読み込み
(x_train, t_train), (x_test, t_test) = keras.datasets.fashion_mnist.load_data()

# 訓練データを正規化
x_train = x_train / 255
# テストデータを正規化
x_test = x_test / 255

# %%
'''
2.モデルの生成
'''
# モデルオブジェクトを生成
model = keras.Sequential([
    # 入力するテンソルの形状を(28, 28)から(784)にフラット化する
    keras.layers.Flatten(input_shape=(28, 28)),
    # 隠れ層のユニット数:256
    # 活性化関数:ReLU
    keras.layers.Dense(256, activation='relu'),
    # 出力層のニューロン数:10
    # 活性化関数:ソフトマックス 
    keras.layers.Dense(10, activation='softmax')
])

# 学習率
learning_rate = 0.1                  
# モデルのコンパイル
model.compile(
    # 損失関数はスパースラベル対応クロスエントロピー誤差
    loss='sparse_categorical_crossentropy',
    # オプティマイザーはAdamax
    optimizer=keras.optimizers.Adamax(learning_rate=0.002),
    # 学習評価として正解率を指定
    metrics=['accuracy']
    )

model.summary() # モデルのサマリー(概要)を出力
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
'''
3. モデルの学習
'''
epoch = 100
# ミニバッチのサイズ
batch_size = 64

history = model.fit(
    x_train,               # 訓練データ
    t_train,               # 正解ラベル
    epochs=epoch,          # エポック数を設定
    batch_size=batch_size, # ミニバッチのサイズを設定
    verbose=1,             # 進捗状況を出力
    validation_split=0.2   # 20パーセントのデータを検証に使用
    )
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/100
# 48000/48000 [==============================] - 4s 73us/sample - loss: 0.5330 - accuracy: 0.8166 - val_loss: 0.4605 - val_accuracy: 0.8387
# Epoch 2/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.4096 - accuracy: 0.8554 - val_loss: 0.3866 - val_accuracy: 0.8624
# Epoch 3/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.3714 - accuracy: 0.8683 - val_loss: 0.3780 - val_accuracy: 0.8648
# Epoch 4/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.3409 - accuracy: 0.8766 - val_loss: 0.3777 - val_accuracy: 0.8658
# Epoch 5/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.3218 - accuracy: 0.8845 - val_loss: 0.3650 - val_accuracy: 0.8683
# Epoch 6/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.3048 - accuracy: 0.8892 - val_loss: 0.3370 - val_accuracy: 0.8788
# Epoch 7/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.2896 - accuracy: 0.8941 - val_loss: 0.3209 - val_accuracy: 0.8845
# Epoch 8/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.2794 - accuracy: 0.8981 - val_loss: 0.3274 - val_accuracy: 0.8835
# Epoch 9/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.2673 - accuracy: 0.9029 - val_loss: 0.3373 - val_accuracy: 0.8761
# Epoch 10/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.2596 - accuracy: 0.9052 - val_loss: 0.3109 - val_accuracy: 0.8864
# Epoch 11/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.2482 - accuracy: 0.9093 - val_loss: 0.3144 - val_accuracy: 0.8863
# Epoch 12/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.2410 - accuracy: 0.9134 - val_loss: 0.3053 - val_accuracy: 0.8914
# Epoch 13/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.2319 - accuracy: 0.9153 - val_loss: 0.3071 - val_accuracy: 0.8913
# Epoch 14/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.2248 - accuracy: 0.9179 - val_loss: 0.3178 - val_accuracy: 0.8878
# Epoch 15/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.2184 - accuracy: 0.9199 - val_loss: 0.2989 - val_accuracy: 0.8927
# Epoch 16/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.2111 - accuracy: 0.9231 - val_loss: 0.3036 - val_accuracy: 0.8921
# Epoch 17/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.2060 - accuracy: 0.9242 - val_loss: 0.3245 - val_accuracy: 0.8871
# Epoch 18/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1996 - accuracy: 0.9274 - val_loss: 0.2956 - val_accuracy: 0.8943
# Epoch 19/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1941 - accuracy: 0.9294 - val_loss: 0.3013 - val_accuracy: 0.8938
# Epoch 20/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.1867 - accuracy: 0.9320 - val_loss: 0.2970 - val_accuracy: 0.8960
# Epoch 21/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.1823 - accuracy: 0.9339 - val_loss: 0.3162 - val_accuracy: 0.8898
# Epoch 22/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.1813 - accuracy: 0.9339 - val_loss: 0.3058 - val_accuracy: 0.8942
# Epoch 23/100
# 48000/48000 [==============================] - 3s 66us/sample - loss: 0.1729 - accuracy: 0.9362 - val_loss: 0.3006 - val_accuracy: 0.8957
# Epoch 24/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.1705 - accuracy: 0.9383 - val_loss: 0.3070 - val_accuracy: 0.8956
# Epoch 25/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.1649 - accuracy: 0.9413 - val_loss: 0.3232 - val_accuracy: 0.8893
# Epoch 26/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.1591 - accuracy: 0.9425 - val_loss: 0.3085 - val_accuracy: 0.8947
# Epoch 27/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.1533 - accuracy: 0.9445 - val_loss: 0.3067 - val_accuracy: 0.8953
# Epoch 28/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.1510 - accuracy: 0.9456 - val_loss: 0.3030 - val_accuracy: 0.8969
# Epoch 29/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.1474 - accuracy: 0.9475 - val_loss: 0.3092 - val_accuracy: 0.8972
# Epoch 30/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.1432 - accuracy: 0.9494 - val_loss: 0.3113 - val_accuracy: 0.8957
# Epoch 31/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.1392 - accuracy: 0.9488 - val_loss: 0.3264 - val_accuracy: 0.8939
# Epoch 32/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.1340 - accuracy: 0.9536 - val_loss: 0.3183 - val_accuracy: 0.8960
# Epoch 33/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.1317 - accuracy: 0.9530 - val_loss: 0.3259 - val_accuracy: 0.8947
# Epoch 34/100
# 48000/48000 [==============================] - 3s 63us/sample - loss: 0.1276 - accuracy: 0.9547 - val_loss: 0.3267 - val_accuracy: 0.8954
# Epoch 35/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.1251 - accuracy: 0.9553 - val_loss: 0.3210 - val_accuracy: 0.8978
# Epoch 36/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.1192 - accuracy: 0.9582 - val_loss: 0.3376 - val_accuracy: 0.8956
# Epoch 37/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.1177 - accuracy: 0.9590 - val_loss: 0.3324 - val_accuracy: 0.8957
# Epoch 38/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.1164 - accuracy: 0.9589 - val_loss: 0.3318 - val_accuracy: 0.8972
# Epoch 39/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.1130 - accuracy: 0.9601 - val_loss: 0.3409 - val_accuracy: 0.8964
# Epoch 40/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.1102 - accuracy: 0.9607 - val_loss: 0.3604 - val_accuracy: 0.8926
# Epoch 41/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.1071 - accuracy: 0.9626 - val_loss: 0.3397 - val_accuracy: 0.8955
# Epoch 42/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.1051 - accuracy: 0.9629 - val_loss: 0.3559 - val_accuracy: 0.8916
# Epoch 43/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0999 - accuracy: 0.9658 - val_loss: 0.3475 - val_accuracy: 0.8940
# Epoch 44/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0977 - accuracy: 0.9656 - val_loss: 0.3495 - val_accuracy: 0.8932
# Epoch 45/100
# 48000/48000 [==============================] - 3s 63us/sample - loss: 0.0964 - accuracy: 0.9661 - val_loss: 0.3418 - val_accuracy: 0.8997
# Epoch 46/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0929 - accuracy: 0.9681 - val_loss: 0.3562 - val_accuracy: 0.8952
# Epoch 47/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0922 - accuracy: 0.9684 - val_loss: 0.3632 - val_accuracy: 0.8947
# Epoch 48/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0869 - accuracy: 0.9707 - val_loss: 0.3618 - val_accuracy: 0.8926
# Epoch 49/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0851 - accuracy: 0.9715 - val_loss: 0.3653 - val_accuracy: 0.8931
# Epoch 50/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0848 - accuracy: 0.9708 - val_loss: 0.3832 - val_accuracy: 0.8911
# Epoch 51/100
# 48000/48000 [==============================] - 3s 63us/sample - loss: 0.0807 - accuracy: 0.9726 - val_loss: 0.3856 - val_accuracy: 0.8929
# Epoch 52/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0799 - accuracy: 0.9724 - val_loss: 0.3671 - val_accuracy: 0.8965
# Epoch 53/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0776 - accuracy: 0.9739 - val_loss: 0.3721 - val_accuracy: 0.8968
# Epoch 54/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0752 - accuracy: 0.9749 - val_loss: 0.3678 - val_accuracy: 0.8969
# Epoch 55/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0724 - accuracy: 0.9761 - val_loss: 0.3739 - val_accuracy: 0.8943
# Epoch 56/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0696 - accuracy: 0.9768 - val_loss: 0.4049 - val_accuracy: 0.8888
# Epoch 57/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0698 - accuracy: 0.9759 - val_loss: 0.3805 - val_accuracy: 0.8982
# Epoch 58/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0686 - accuracy: 0.9775 - val_loss: 0.3833 - val_accuracy: 0.8932
# Epoch 59/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0667 - accuracy: 0.9780 - val_loss: 0.3827 - val_accuracy: 0.8978
# Epoch 60/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0640 - accuracy: 0.9789 - val_loss: 0.3850 - val_accuracy: 0.8964
# Epoch 61/100
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0619 - accuracy: 0.9796 - val_loss: 0.3939 - val_accuracy: 0.8957
# Epoch 62/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.0613 - accuracy: 0.9794 - val_loss: 0.4121 - val_accuracy: 0.8929
# Epoch 63/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0585 - accuracy: 0.9806 - val_loss: 0.3926 - val_accuracy: 0.8965
# Epoch 64/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0571 - accuracy: 0.9812 - val_loss: 0.4086 - val_accuracy: 0.8946
# Epoch 65/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0551 - accuracy: 0.9817 - val_loss: 0.4310 - val_accuracy: 0.8888
# Epoch 66/100
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0550 - accuracy: 0.9819 - val_loss: 0.4094 - val_accuracy: 0.8938
# Epoch 67/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0534 - accuracy: 0.9834 - val_loss: 0.4191 - val_accuracy: 0.8958
# Epoch 68/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0510 - accuracy: 0.9833 - val_loss: 0.4206 - val_accuracy: 0.8932
# Epoch 69/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0518 - accuracy: 0.9822 - val_loss: 0.4305 - val_accuracy: 0.8943
# Epoch 70/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0487 - accuracy: 0.9842 - val_loss: 0.4267 - val_accuracy: 0.8963
# Epoch 71/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0496 - accuracy: 0.9839 - val_loss: 0.4301 - val_accuracy: 0.8960
# Epoch 72/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0464 - accuracy: 0.9854 - val_loss: 0.4291 - val_accuracy: 0.8961
# Epoch 73/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0442 - accuracy: 0.9865 - val_loss: 0.4432 - val_accuracy: 0.8927
# Epoch 74/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0445 - accuracy: 0.9854 - val_loss: 0.4393 - val_accuracy: 0.8950
# Epoch 75/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0435 - accuracy: 0.9859 - val_loss: 0.4409 - val_accuracy: 0.8963
# Epoch 76/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0424 - accuracy: 0.9865 - val_loss: 0.4437 - val_accuracy: 0.8962
# Epoch 77/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0397 - accuracy: 0.9877 - val_loss: 0.4390 - val_accuracy: 0.8962
# Epoch 78/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0403 - accuracy: 0.9873 - val_loss: 0.4507 - val_accuracy: 0.8934
# Epoch 79/100
# 48000/48000 [==============================] - 3s 62us/sample - loss: 0.0398 - accuracy: 0.9873 - val_loss: 0.4753 - val_accuracy: 0.8903
# Epoch 80/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0377 - accuracy: 0.9884 - val_loss: 0.4720 - val_accuracy: 0.8905
# Epoch 81/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0380 - accuracy: 0.9878 - val_loss: 0.4531 - val_accuracy: 0.8950
# Epoch 82/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0360 - accuracy: 0.9887 - val_loss: 0.4780 - val_accuracy: 0.8920
# Epoch 83/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0349 - accuracy: 0.9895 - val_loss: 0.4711 - val_accuracy: 0.8943
# Epoch 84/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0344 - accuracy: 0.9895 - val_loss: 0.4516 - val_accuracy: 0.8958
# Epoch 85/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0345 - accuracy: 0.9892 - val_loss: 0.4656 - val_accuracy: 0.8953
# Epoch 86/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0319 - accuracy: 0.9899 - val_loss: 0.4681 - val_accuracy: 0.8939
# Epoch 87/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0315 - accuracy: 0.9902 - val_loss: 0.4837 - val_accuracy: 0.8942
# Epoch 88/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0320 - accuracy: 0.9901 - val_loss: 0.4861 - val_accuracy: 0.8927
# Epoch 89/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0308 - accuracy: 0.9902 - val_loss: 0.4906 - val_accuracy: 0.8934
# Epoch 90/100
# 48000/48000 [==============================] - 3s 67us/sample - loss: 0.0307 - accuracy: 0.9903 - val_loss: 0.4783 - val_accuracy: 0.8958
# Epoch 91/100
# 48000/48000 [==============================] - 3s 61us/sample - loss: 0.0300 - accuracy: 0.9908 - val_loss: 0.4882 - val_accuracy: 0.8945
# Epoch 92/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0268 - accuracy: 0.9920 - val_loss: 0.4880 - val_accuracy: 0.8942
# Epoch 93/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0282 - accuracy: 0.9911 - val_loss: 0.4940 - val_accuracy: 0.8940
# Epoch 94/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0259 - accuracy: 0.9922 - val_loss: 0.4972 - val_accuracy: 0.8937
# Epoch 95/100
# 48000/48000 [==============================] - 3s 59us/sample - loss: 0.0265 - accuracy: 0.9919 - val_loss: 0.4962 - val_accuracy: 0.8950
# Epoch 96/100
# 48000/48000 [==============================] - 3s 60us/sample - loss: 0.0266 - accuracy: 0.9921 - val_loss: 0.5135 - val_accuracy: 0.8929
# Epoch 97/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0246 - accuracy: 0.9930 - val_loss: 0.5082 - val_accuracy: 0.8957
# Epoch 98/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0232 - accuracy: 0.9934 - val_loss: 0.5112 - val_accuracy: 0.8931
# Epoch 99/100
# 48000/48000 [==============================] - 3s 57us/sample - loss: 0.0231 - accuracy: 0.9931 - val_loss: 0.5239 - val_accuracy: 0.8958
# Epoch 100/100
# 48000/48000 [==============================] - 3s 58us/sample - loss: 0.0215 - accuracy: 0.9936 - val_loss: 0.5360 - val_accuracy: 0.8927
# Wall time: 4min 46s

# %%
'''
4. テストデータによるモデルの評価
'''
# 学習済みのモデルにテストデータを入力して損失と精度を取得
test_loss, test_acc = model.evaluate(x_test, t_test, verbose=0)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
# Out:
# test_loss: 0.558754499694705
# test_acc: 0.8907
